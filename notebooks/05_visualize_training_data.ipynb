# %%
import pandas as pd
from src.paths import TRANSFORMED_DATA_DIR

features_and_targets = pd.read_parquet(TRANSFORMED_DATA_DIR / 'tabular_data.parquet')
features_and_targets
# Out:
#        rides_previous_672_hour  rides_previous_671_hour  \
# 0                         11.0                     15.0
# 1                          1.0                      0.0
# 2                          0.0                      1.0
# 3                          1.0                      1.0
# 4                          0.0                      0.0
# ...                        ...                      ...
# 88289                      0.0                      0.0
# 88290                      0.0                      0.0
# 88291                      0.0                      0.0
# 88292                      0.0                      0.0
# 88293                      0.0                      0.0
#
#        rides_previous_670_hour  rides_previous_669_hour  \
# 0                         26.0                      8.0
# 1                          2.0                      0.0
# 2                          0.0                      0.0
# 3                          0.0                      0.0
# ...

# %%
features = features_and_targets.drop(columns='target_rides_next_hour')
targets = features_and_targets['target_rides_next_hour']

# %%
from src.plot import plot_one_sample

plot_one_sample(features, targets, example_id=2979)
